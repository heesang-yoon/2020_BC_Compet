# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
from matplotlib import rcParams
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)


rcParams['axes.unicode_minus'] = False
pd.options.display.float_format = '{:.0f}'.format

# %%
import os
import sys
import urllib.request
import json



client_id = "2pL5U_GDk6oXyimHdc1x"
client_secret = "8dhE5EwfzD"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-01-01\",\"endDate\":\"2020-05-31\",\"timeUnit\":\"month\",\
\"keywordGroups\":\
[{\"groupName\":\"분당 맛집\",\"keywords\":[\"분당 맛집\"]},\
{\"groupName\":\"청운효자동 맛집\",\"keywords\":[\"청운효자동 맛집\", \"효자동 맛집\", \"청운동 맛집\", \"신교동 맛집\", \"궁정동 맛집\", \"창성동 맛집\", \"통인동 맛집\", \"누상동 맛집\", \"누하동 맛집\", \"옥인동 맛집\"]},\
{\"groupName\":\"사직동 맛집\",\"keywords\":[\"사직동 맛집\", \"제부동 맛집\", \"도렴동 맛집\", \"당주동 맛집\", \"내수동 맛집\", \"신문로1가 맛집\", \"필운동 맛집\", \"내자동 맛집\", \"통의동 맛집\", \"적선동 맛집\"]},\
{\"groupName\":\"부암동 맛집\",\"keywords\":[\"부암동 맛집\", \"홍지동 맛집\", \"신영동 맛집\"]},\
{\"groupName\":\"무악동 맛집\",\"keywords\":[\"무악동 맛집\"]}]}"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))


response_body = response.read()
response_body.decode('utf-8')


scraped = response_body.decode('utf-8')
a = json.loads(scraped)
dong_dict_list1 = []
for dong in a['results']:
    dong_dict_list1.append(dong['data'])

# %%
import os
import sys
import urllib.request
import json

client_id = "2pL5U_GDk6oXyimHdc1x"
client_secret = "8dhE5EwfzD"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-01-01\",\"endDate\":\"2020-05-31\",\"timeUnit\":\"month\",\
\"keywordGroups\":\
[{\"groupName\":\"분당 맛집\",\"keywords\":[\"분당 맛집\"]},\
{\"groupName\":\"교남동 맛집\",\"keywords\":[\"교남동 맛집\", \"평동 맛집\", \"송월동 맛집\", \"홍파동 맛집\", \"교북동 맛집\", \"행촌동 맛집\"]},\
{\"groupName\":\"가회동 맛집\",\"keywords\":[\"가회동 맛집\", \"재동 맛집\", \"계동 맛집\", \"원서동 맛집\"]},\
{\"groupName\":\"숭인동 맛집\",\"keywords\":[\"숭인동 맛집\",\"숭인1동 맛집\",\"숭인2동 맛집\"]},\
{\"groupName\":\"평창동 맛집\",\"keywords\":[\"평창동 맛집\", \"구기동 맛집\"]}]}"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))


response_body = response.read()
response_body.decode('utf-8')


scraped = response_body.decode('utf-8')
a = json.loads(scraped)
dong_dict_list2 = []
for dong in a['results']:
    dong_dict_list2.append(dong['data'])

# %%
import os
import sys
import urllib.request
import json

client_id = "2pL5U_GDk6oXyimHdc1x"
client_secret = "8dhE5EwfzD"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-01-01\",\"endDate\":\"2020-05-31\",\"timeUnit\":\"month\",\
\"keywordGroups\":\
[{\"groupName\":\"분당 맛집\",\"keywords\":[\"분당 맛집\"]},\
{\"groupName\":\"종로 맛집\",\"keywords\":[\"종로 맛집\", \"청진동 맛집\", \"서린동 맛집\", \"수송동 맛집\", \"공평동 맛집\", \"관훈동 맛집\", \"견지동 맛집\", \"익선동 맛집\", \"경운동 맛집\", \"관철동 맛집\", \"인사동 맛집\", \"낙원동 맛집\", \"훈정동 맛집\", \"묘동 맛집\", \"봉익동 맛집\", \"돈의동 맛집\", \"장사동 맛집\", \"인의동 맛집\", \"관수동 맛집\"]},\
{\"groupName\":\"이화동 맛집\",\"keywords\":[\"이화동 맛집\", \"낙산공원 맛집\",\"연건동 맛집\",\"동숭동 맛집\"]},\
{\"groupName\":\"혜화동 맛집\",\"keywords\":[\"혜화동 맛집\", \"명륜동1가 맛집\", \"명륜동2가 맛집\", \"명륜동3가 맛집\", \"명륜동4가 맛집\", \"명륜동 맛집\"]},\
{\"groupName\":\"창신동 맛집\",\"keywords\":[\"창신동 맛집\",\"창신1동 맛집\",\"창신2동 맛집\", \"창신3동 맛집\"]}]}"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))


response_body = response.read()
response_body.decode('utf-8')


scraped = response_body.decode('utf-8')
a = json.loads(scraped)
dong_dict_list3 = []
for dong in a['results']:
    dong_dict_list3.append(dong['data'])

# %%
import os
import sys
import urllib.request
import json

client_id = "2pL5U_GDk6oXyimHdc1x"
client_secret = "8dhE5EwfzD"
url = "https://openapi.naver.com/v1/datalab/search";
body = "{\"startDate\":\"2017-01-01\",\"endDate\":\"2020-05-31\",\"timeUnit\":\"month\",\
\"keywordGroups\":\
[{\"groupName\":\"분당 맛집\",\"keywords\":[\"분당 맛집\"]},\
{\"groupName\":\"삼청동 맛집\",\"keywords\":[\"삼청동 맛집\", \"팔판동 맛집\", \"효자동 맛집\", \"안국동 맛집\", \"소격동 맛집\", \"화동 맛집\", \"사간동 맛집\", \"송현동 맛집\"]}]}"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
request.add_header("Content-Type","application/json")
response = urllib.request.urlopen(request, data=body.encode("utf-8"))


response_body = response.read()
response_body.decode('utf-8')


scraped = response_body.decode('utf-8')
a = json.loads(scraped)
dong_dict_list4 = []
for dong in a['results']:
    dong_dict_list4.append(dong['data'])

# %%
periods_dict2 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list1[1][num]['period'] == periods[i]:
        periods_dict2[dong_dict_list1[1][num]['period']] = float(dong_dict_list1[1][num]['ratio'])/float(dong_dict_list1[0][i]['ratio'])
        num += 1
    else:
        periods_dict2[periods[i]] = 0

# %%
periods_dict3 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list1[2][num]['period'] == periods[i]:
        periods_dict3[dong_dict_list1[2][num]['period']] = float(dong_dict_list1[2][num]['ratio'])/float(dong_dict_list1[0][i]['ratio'])
        num += 1
    else:
        periods_dict3[periods[i]] = 0

# %%
periods_dict4 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list1[3][num]['period'] == periods[i]:
        periods_dict4[dong_dict_list1[3][num]['period']] = float(dong_dict_list1[3][num]['ratio'])/float(dong_dict_list1[0][i]['ratio'])
        num += 1
    else:
        periods_dict4[periods[i]] = 0

# %%
periods_dict5 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list1[4][num]['period'] == periods[i]:
        periods_dict5[dong_dict_list1[4][num]['period']] = float(dong_dict_list1[4][num]['ratio'])/float(dong_dict_list1[0][i]['ratio'])
        num += 1
    else:
        periods_dict5[periods[i]] = 0

# %%
periods_dict6 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list2[1][num]['period'] == periods[i]:
        periods_dict6[dong_dict_list2[1][num]['period']] = float(dong_dict_list2[1][num]['ratio'])/float(dong_dict_list2[0][i]['ratio'])
        num += 1
    else:
        periods_dict6[periods[i]] = 0

# %%
periods_dict7 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list2[2][num]['period'] == periods[i]:
        periods_dict7[dong_dict_list2[2][num]['period']] = float(dong_dict_list2[2][num]['ratio'])/float(dong_dict_list2[0][i]['ratio'])
        num += 1
    else:
        periods_dict7[periods[i]] = 0

# %%
periods_dict8 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list2[3][num]['period'] == periods[i]:
        periods_dict8[dong_dict_list2[3][num]['period']] = float(dong_dict_list2[3][num]['ratio'])/float(dong_dict_list2[0][i]['ratio'])
        num += 1
    else:
        periods_dict8[periods[i]] = 0

# %%
periods_dict9 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list2[4][num]['period'] == periods[i]:
        periods_dict9[dong_dict_list2[4][num]['period']] = float(dong_dict_list2[4][num]['ratio'])/float(dong_dict_list2[0][i]['ratio'])
        num += 1
    else:
        periods_dict9[periods[i]] = 0

# %%
periods_dict10 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list3[1][num]['period'] == periods[i]:
        periods_dict10[dong_dict_list3[1][num]['period']] = float(dong_dict_list3[1][num]['ratio'])/float(dong_dict_list3[0][i]['ratio'])
        num += 1
    else:
        periods_dict10[periods[i]] = 0

# %%
periods_dict11 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list3[2][num]['period'] == periods[i]:
        periods_dict11[dong_dict_list3[2][num]['period']] = float(dong_dict_list3[2][num]['ratio'])/float(dong_dict_list3[0][i]['ratio'])
        num += 1
    else:
        periods_dict11[periods[i]] = 0

# %%
periods_dict12 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list3[3][num]['period'] == periods[i]:
        periods_dict12[dong_dict_list3[3][num]['period']] = float(dong_dict_list3[3][num]['ratio'])/float(dong_dict_list3[0][i]['ratio'])
        num += 1
    else:
        periods_dict12[periods[i]] = 0

# %%
periods_dict13 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list3[4][num]['period'] == periods[i]:
        periods_dict13[dong_dict_list3[4][num]['period']] = float(dong_dict_list3[4][num]['ratio'])/float(dong_dict_list3[0][i]['ratio'])
        num += 1
    else:
        periods_dict13[periods[i]] = 0

# %%
periods_dict14 = dict()
num = 0
for i in range(len(periods)):
    

    
    if dong_dict_list3[4][num]['period'] == periods[i]:
        periods_dict14[dong_dict_list4[1][num]['period']] = float(dong_dict_list4[1][num]['ratio'])/float(dong_dict_list4[0][i]['ratio'])
        num += 1
    else:
        periods_dict14[periods[i]] = 0

# %%
periods_dict1 = dict()
for i in range(len(periods)):
    periods_dict1[periods[i]] = 1

# %%
# 삼청동
# 청운효자동
# 사직동
# 부암동
# 무악동
# 교남동
# 가회동
# 숭인동
# 평창동
# 종로
# 이화동
# 혜화동
# 창신동

# %%
import pandas as pd
a = pd.DataFrame(data = periods_dict1.values(), index = periods)

# %%
a['청운효자동'] = periods_dict2.values()
a['사직동'] = periods_dict3.values()
a['부암동'] = periods_dict4.values()
a['무악동'] = periods_dict5.values()
a['교남동'] = periods_dict6.values()
a['가회동'] = periods_dict7.values()
a['숭인동'] = periods_dict8.values()
a['평창동'] = periods_dict9.values()
a['종로'] = periods_dict10.values()
a['이화동'] = periods_dict11.values()
a['혜화동'] = periods_dict12.values()
a['창신동'] = periods_dict13.values()
a['삼청동'] = periods_dict14.values()

# %%
a.rename(columns = {0 : '분당'}, inplace = True)

# %%
dong_search = a.copy()

# %%
d_list = list(dong_search.index)

# %%
c_list = []
for a in d_list:
    c_list.append(a.replace('-', '').replace('-','')[2:6])

# %%
dong_search.index = c_list

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
dong_search = dong_search*100

# %%
dong_search.loc['1718증감률'] = 0
dong_search.loc['1819증감률'] = 0
dong_search.loc['1920증감률'] = 0

# %%
for dong in dong_search.columns:
    a = dong_search.loc['1704', dong] 
    b = dong_search.loc['1705', dong] 
     
    d = dong_search.loc['1804', dong] 
    e = dong_search.loc['1805', dong]
    result = (d+e-a-b)/(a+b)*100
    dong_search.loc['1718증감률', dong] = result



for dong in dong_search.columns:
    a = dong_search.loc['1804', dong] 
    b = dong_search.loc['1805', dong] 
     
    d = dong_search.loc['1904', dong] 
    e = dong_search.loc['1905', dong]
    result = (d+e-a-b)/(a+b)*100
    dong_search.loc['1819증감률', dong] = result



for dong in dong_search.columns:
    a = dong_search.loc['1904', dong] 
    b = dong_search.loc['1905', dong] 
     
    d = dong_search.loc['2004', dong] 
    e = dong_search.loc['2005', dong]
    result = (d+e-a-b)/(a+b)*100
    dong_search.loc['1920증감률', dong] = result

# %%
dong_search.drop('분당',axis = 1, inplace = True)

# %%
dong_search
# Out:
#             청운효자동       사직동       부암동      무악동      교남동       가회동       숭인동  \
# 1701      8.02432  18.54430  20.42135  0.00000  0.79535   3.63391   0.68577
# 1702      7.82958  16.66916  25.80424  0.01168  0.71450   4.41895   0.80799
# 1703      8.22490  16.84716  24.83297  0.00878  1.01623   5.36781   0.76481
# 1704      8.64416  17.24537  25.68968  0.01120  0.97497   5.77708   0.64252
# 1705      9.56228  14.68019  24.36045  0.00896  1.00804   4.13672   0.64515
# 1706      6.20512  10.83076  17.94390  0.00000  0.63584   3.16258   0.48966
# 1707      7.92162  14.91647  21.29804  0.00000  0.93640   3.37298   0.66964
# 1708      9.78547  16.82743  27.23004  0.01341  0.96057   3.82618   0.66005
# 1709      8.50621  15.71250  26.48491  0.01450  0.85163   3.89257   0.53681
# 1710     10.47523  17.53540  32.44333  0.02361  0.85061   5.24235   0.60330
# 1711      8.70432  15.04301  22.52301  0.00000  0.66883   4.21249   0.57145
# ...

# %%
dong_search.head(6)
# Out:
#        청운효자동      사직동      부암동     무악동     교남동     가회동     숭인동      평창동  \
# 1701 8.02432 18.54430 20.42135 0.00000 0.79535 3.63391 0.68577  9.34815
# 1702 7.82958 16.66916 25.80424 0.01168 0.71450 4.41895 0.80799  9.57746
# 1703 8.22490 16.84716 24.83297 0.00878 1.01623 5.36781 0.76481 11.24023
# 1704 8.64416 17.24537 25.68968 0.01120 0.97497 5.77708 0.64252 12.29197
# 1705 9.56228 14.68019 24.36045 0.00896 1.00804 4.13672 0.64515 12.62227
# 1706 6.20512 10.83076 17.94390 0.00000 0.63584 3.16258 0.48966  9.08366
#
#             종로     이화동      혜화동     창신동       삼청동
# 1701 313.74384 2.09798 16.01854 2.32066 100.56913
# 1702 308.45072 2.78292 17.49048 2.42228  94.16536
# 1703 330.46456 3.75198 16.46209 3.92432 106.13792
# 1704 333.65598 4.80582 16.29839 2.99407 120.22637
# 1705 325.94795 3.94255 15.72256 2.99721  96.86683
# 1706 237.21771 2.51958 11.20513 2.12618  71.25386

# %%
dong_search2 = dong_search.drop(['무악동', '교남동', '숭인동'], axis = 1)

# %%
dong_search2
# Out:
#             청운효자동       사직동       부암동       가회동      평창동        종로      이화동  \
# 1701      8.02432  18.54430  20.42135   3.63391  9.34815 313.74384  2.09798
# 1702      7.82958  16.66916  25.80424   4.41895  9.57746 308.45072  2.78292
# 1703      8.22490  16.84716  24.83297   5.36781 11.24023 330.46456  3.75198
# 1704      8.64416  17.24537  25.68968   5.77708 12.29197 333.65598  4.80582
# 1705      9.56228  14.68019  24.36045   4.13672 12.62227 325.94795  3.94255
# 1706      6.20512  10.83076  17.94390   3.16258  9.08366 237.21771  2.51958
# 1707      7.92162  14.91647  21.29804   3.37298 10.13268 317.11796  3.19419
# 1708      9.78547  16.82743  27.23004   3.82618 11.86895 350.66619  4.85112
# 1709      8.50621  15.71250  26.48491   3.89257 11.93018 309.79463  8.60341
# 1710     10.47523  17.53540  32.44333   5.24235 13.65246 382.31651 12.32768
# 1711      8.70432  15.04301  22.52301   4.21249 11.02526 359.00689  5.54533
# ...

# %%
dong_search2.loc['1718증감률'].mean()
# Out:
# -2.5258939360055765

# %%
dong_search2.loc['1819증감률'].mean()
# Out:
# 20.898359954127532

# %%
dong_search2.loc['1920증감률'].mean()
# Out:
# -16.88697732744056

# %%
a = dong_search.loc['1718증감률']
b = dong_search.loc['1819증감률']
c = dong_search.loc['1920증감률']
label = dong_search.columns

ax = plt.figure(figsize = (16,10))
x = np.arange(int(len(label)))
plt.bar(x-0.2, a, label = '17-18증감률(4월,5월 기준)', width = 0.2, color = '#48a999')
plt.bar(x-0.0, b, label = '18-19증감률(4월,5월 기준)', width = 0.2, color = '#00796b')
plt.bar(x+0.2, c, label = '19-20증감률(4월,5월 기준)', width = 0.2, color = '#004d40')
plt.xticks(x, label,fontsize= 15)
plt.xlabel('행정동', fontsize = 20)
plt.ylabel('증감률(%)', fontsize= 20)
plt.yticks(fontsize = 15)
plt.axhline(color = 'black')
plt.grid(axis = 'y', alpha = 0.7)
plt.title('최근 3년간 종로구 행정구역 검색량 증감률', fontsize= 25)
plt.legend(fontsize= 14)
# plt.savefig('최근 3년간 종로구 행정구역 검색량 증감률')
plt.show()

# %%
a = dong_search2.loc['1718증감률']
b = dong_search2.loc['1819증감률']
c = dong_search2.loc['1920증감률']
label = dong_search2.columns

ax = plt.figure(figsize = (16,10))
x = np.arange(int(len(label)))
plt.bar(x-0.2, a, label = '17-18증감률(4월,5월 기준)', width = 0.2, color = '#48a999')
plt.bar(x-0.0, b, label = '18-19증감률(4월,5월 기준)', width = 0.2, color = '#00796b')
plt.bar(x+0.2, c, label = '19-20증감률(4월,5월 기준)', width = 0.2, color = '#004d40')
plt.xticks(x, label,fontsize= 15)
plt.xlabel('행정동', fontsize = 20)
plt.ylabel('증감률(%)', fontsize= 20)
plt.yticks(fontsize = 15)
plt.axhline(color = 'black')
plt.grid(axis = 'y', alpha = 0.7)
plt.title('최근 3년간 종로구 행정구역 검색량 증감률', fontsize= 25)
plt.legend(fontsize= 14)
# plt.savefig('최근 3년간 주요 종로구 행정구역 검색량 증감률')
plt.show()

# %%
fig = plt.figure(figsize= ( 12, 12))
ax1 = fig.add_subplot(3,1,1)
plt.bar(dong_search.columns, dong_search.loc['1718증감률'])
plt.axhline( y = 0, color = 'black')
plt.title('1718증감률', fontsize = 20)

ax2 = fig.add_subplot(3,1,2)
plt.bar(dong_search.columns, dong_search.loc['1819증감률'])
plt.axhline( y = 0, color = 'black')
plt.title('1819증감률', fontsize = 20)

ax3 = fig.add_subplot(3,1,3)
plt.bar(dong_search.columns, dong_search.loc['1920증감률'])
plt.axhline( y = 0, color = 'black')
plt.title('1920증감률')
# Out:
# Text(0.5, 1.0, '1920증감률')

# %%
dong_list = ['삼청동', '청운효자동','사직동','부암동','무악동','교남동','가회동','숭인동','평창동','종로','이화동','혜화동','창신동']

# %%
dong_search_index = []
for i in range(len(dong_search.index)):
    if i % 2 == 0:
        dong_search_index.append(dong_search.index[i])

# %%
plt.figure(figsize = (18,8))

plt.plot(dong_search['종로'].loc[:'2005'], label = '종로', linewidth = 3, color = '#ff4081')
plt.plot(dong_search['삼청동'].loc[:'2005'], label = '삼청동', linewidth = 3, color = '#ff6e40')
# plt.plot(dong_search['부암동'].loc[:'2005'], label = '부암동', linewidth = 3)
# plt.plot(dong_search['청운효자동'].loc[:'2005'], label = '청운효자동', linewidth = 3)
# plt.plot(dong_search['사직동'].loc[:'2005'], label = '사직동', linewidth = 3)
# # plt.plot(dong_search['무악동'].loc[:'2005'], label = '무악동', linewidth = 3)
# # plt.plot(dong_search['교남동'].loc[:'2005'], label = '교남동', linewidth = 3)
# plt.plot(dong_search['가회동'].loc[:'2005'], label = '가회동', linewidth = 3)
# # plt.plot(dong_search['숭인동'].loc[:'2005'], label = '숭인동', linewidth = 3)
# plt.plot(dong_search['평창동'].loc[:'2005'], label = '평창동', linewidth = 3)
# plt.plot(dong_search['이화동'].loc[:'2005'], label = '이화동', linewidth = 3)
# plt.plot(dong_search['혜화동'].loc[:'2005'], label = '혜화동', linewidth = 3)
# plt.plot(dong_search['창신동'].loc[:'2005'], label = '창신동', linewidth = 3)

ax = plt.subplot()
ax.set_xticks(ticks = dong_search_index)
ax.set_xticklabels(dong_search_index, rotation = 30, fontsize = 15)
# ax.set_yticks(ticks = [0,5 , 10, 15, 20, 25, 30, 35, 40])
# ax.set_yticklabels([0,5 , 10, 15, 20, 25, 30, 35, 40], fontsize = 15)


plt.grid()

plt.show()
# Out:
# <ipython-input-958-b620df2fe53d>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %%
plt.figure(figsize = (18,8))

# plt.plot(dong_search['종로'].loc[:'2005'], label = '종로', linewidth = 3)
# plt.plot(dong_search['삼청동'].loc[:'2005'], label = '삼청동', linewidth = 3)
plt.plot(dong_search['부암동'].loc[:'2005'], label = '부암동', linewidth = 3, color = '#ab47bc')
plt.plot(dong_search['청운효자동'].loc[:'2005'], label = '청운효자동', linewidth = 3, color = '#7e57c2')
plt.plot(dong_search['사직동'].loc[:'2005'], label = '사직동', linewidth = 3, color = '#9fa8da')
plt.plot(dong_search['무악동'].loc[:'2005'], label = '무악동', linewidth = 3, color = '#9e9e9e')
plt.plot(dong_search['교남동'].loc[:'2005'], label = '교남동', linewidth = 3, color = '#37474f')
plt.plot(dong_search['가회동'].loc[:'2005'], label = '가회동', linewidth = 3, color = '#42a5f5')
plt.plot(dong_search['숭인동'].loc[:'2005'], label = '숭인동', linewidth = 3, color = '#616161')
plt.plot(dong_search['평창동'].loc[:'2005'], label = '평창동', linewidth = 3, color = '#00acc1')
plt.plot(dong_search['이화동'].loc[:'2005'], label = '이화동', linewidth = 3, color = '#536dfe')
plt.plot(dong_search['혜화동'].loc[:'2005'], label = '혜화동', linewidth = 3, color = '#1de9b6')
plt.plot(dong_search['창신동'].loc[:'2005'], label = '창신동', linewidth = 3, color = '#00c853')

ax = plt.subplot()
ax.set_xticks(ticks = dong_search_index)
ax.set_xticklabels(dong_search_index, rotation = 30, fontsize = 15)
# ax.set_yticks(ticks = [0,5 , 10, 15, 20, 25, 30, 35, 40])
# ax.set_yticklabels([0,5 , 10, 15, 20, 25, 30, 35, 40], fontsize = 15)

plt.grid()
plt.legend()

plt.show()
# Out:
# <ipython-input-960-39909bd06785>:17: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %%
dong_list = ['삼청동', '청운효자동','사직동','부암동','무악동','교남동','가회동','숭인동','평창동','종로','이화동','혜화동','창신동']

# %%
fig, ax = plt.subplots(nrows = 7, ncols = 2, figsize = (30, 20))
plt.subplots_adjust(hspace = 0.8)
num = 0
for i in range(7):
    for j in range(2):
        ax[i][j].plot(dong_search[dong_list[num]], label = dong_list[num])
        ax[i][j].set_title(dong_list[num], fontsize = 25)
        ax[i][j].set_xticks(ticks = dong_search_index)
        ax[i][j].set_xticklabels(dong_search_index, rotation = 30, fontsize = 12)
        ax[i][j].grid()
        ax[i][j].axvline(x = '1905', color = 'red', linewidth = 10, alpha = 0.3, linestyle = '-')
        ax[i][j].axvline(x = '2005', color = 'red', linewidth = 10, alpha = 0.3, linestyle = '-')
#         plt.savefig(dong_list[num] + '검색량 변화.png')
        num += 1


plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-719-9be0c6f6c049> in <module>
#       4 for i in range(7):
#       5     for j in range(2):
# ----> 6         ax[i][j].plot(dong_search[dong_list[num]], label = dong_list[num])
#       7         ax[i][j].set_title(dong_list[num], fontsize = 25)
#       8         ax[i][j].set_xticks(ticks = dong_search_index)
#
# IndexError: list index out of range

# %%
dong_search_part = dong_search.loc[['1904','1905','1906', '2003','2004','2005']]

# %%
dong_search_part
# Out:
#        분당   청운효자동      사직동      부암동     무악동     교남동     가회동     숭인동      평창동  \
# 1904  100 6.66974 14.97330 25.11941 0.02206 1.81244 5.81870 0.69447 15.13386
# 1905  100 7.11296 14.98925 26.96671 0.00941 1.63594 7.91774 0.78215 16.37075
# 1906  100 7.51153 15.30901 25.82918 0.00000 1.41973 5.55611 0.63434 15.68560
# 2003  100 5.63655  9.99977 40.15407 0.00000 1.76778 2.35564 0.70031 14.59222
# 2004  100 5.45047 10.39068 33.91324 0.01753 1.65204 3.34714 0.61552 14.84451
# 2005  100 7.63927 12.36442 33.45558 0.02985 1.74562 3.67464 0.57855 16.73276
#
#             종로     이화동      혜화동     창신동      삼청동
# 1904 484.55107 1.11998 17.92378 3.13108 89.56284
# 1905 541.57717 1.03277 19.20915 3.10603 94.23461
# 1906 479.32629 0.94643 17.66918 2.99248 43.14396
# 2003 294.64797 0.58783  8.99598 1.91418 58.08025
# 2004 286.60979 0.69367  9.34298 2.36483 66.68155
# 2005 292.29257 0.71213 10.24775 2.66390 74.46941

# %%
dong_search_part = dong_search_part.T

# %%
dong_search_part
# Out:
#            1904      1905      1906      2003      2004      2005
# 분당    100.00000 100.00000 100.00000 100.00000 100.00000 100.00000
# 청운효자동   6.66974   7.11296   7.51153   5.63655   5.45047   7.63927
# 사직동    14.97330  14.98925  15.30901   9.99977  10.39068  12.36442
# 부암동    25.11941  26.96671  25.82918  40.15407  33.91324  33.45558
# 무악동     0.02206   0.00941   0.00000   0.00000   0.01753   0.02985
# 교남동     1.81244   1.63594   1.41973   1.76778   1.65204   1.74562
# 가회동     5.81870   7.91774   5.55611   2.35564   3.34714   3.67464
# 숭인동     0.69447   0.78215   0.63434   0.70031   0.61552   0.57855
# 평창동    15.13386  16.37075  15.68560  14.59222  14.84451  16.73276
# 종로    484.55107 541.57717 479.32629 294.64797 286.60979 292.29257
# 이화동     1.11998   1.03277   0.94643   0.58783   0.69367   0.71213
# 혜화동    17.92378  19.20915  17.66918   8.99598   9.34298  10.24775
# 창신동     3.13108   3.10603   2.99248   1.91418   2.36483   2.66390
# ...

# %%
dong_search_part['증감률'] = ''
for i in range(len(dong_search_part)):
    a = dong_search_part.loc[dong_search_part.index[i]][0]
    b = dong_search_part.loc[dong_search_part.index[i]][1]
    c = dong_search_part.loc[dong_search_part.index[i]][2]
    d = dong_search_part.loc[dong_search_part.index[i]][3]
    e = dong_search_part.loc[dong_search_part.index[i]][4]
    f = dong_search_part.loc[dong_search_part.index[i]][5]
    
    dong_search_part['증감률'][i] = (d+e+f-a-b-c)/(a+b+c)*100
# Out:
# <ipython-input-724-811022126011>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dong_search_part['증감률'][i] = (d+e+f-a-b-c)/(a+b+c)*100

# %%
dong_search_part
# Out:
#            1904      1905      1906      2003      2004      2005       증감률
# 분당    100.00000 100.00000 100.00000 100.00000 100.00000 100.00000   0.00000
# 청운효자동   6.66974   7.11296   7.51153   5.63655   5.45047   7.63927 -12.05931
# 사직동    14.97330  14.98925  15.30901   9.99977  10.39068  12.36442 -27.64801
# 부암동    25.11941  26.96671  25.82918  40.15407  33.91324  33.45558  37.99970
# 무악동     0.02206   0.00941   0.00000   0.00000   0.01753   0.02985  50.52442
# 교남동     1.81244   1.63594   1.41973   1.76778   1.65204   1.74562   6.10767
# 가회동     5.81870   7.91774   5.55611   2.35564   3.34714   3.67464 -51.39359
# 숭인동     0.69447   0.78215   0.63434   0.70031   0.61552   0.57855 -10.25916
# 평창동    15.13386  16.37075  15.68560  14.59222  14.84451  16.73276  -2.16298
# 종로    484.55107 541.57717 479.32629 294.64797 286.60979 292.29257 -41.97431
# 이화동     1.11998   1.03277   0.94643   0.58783   0.69367   0.71213 -35.67230
# ...

# %%
a = dong_search2.copy()

# %%
a.drop(['1718증감률','1819증감률','1920증감률'], inplace = True)

# %%
a1 = a['부암동']

# %%
a2 = a['평창동']
a3= a['이화동']

# %%
len(a1)
# Out:
# 41

# %%
plt.figure(figsize= (18,6))
plt.plot(a1, color = '#00897b', marker = 'o', linewidth = 3, markersize= 8)
ax = plt.subplot()
ax.set_facecolor('#eeeeee')
ax.set_xticks(range(len(a1)))
ax.set_xticklabels(a1.index, fontsize= 12, rotation = 30)
ax.set_yticks([15,20,25,30,35,40])
ax.set_yticklabels([15,20,25,30,35,40], fontsize= 12)
ax.set_title('부암동 검색량 추이', fontsize= 25)
ax.set_xlabel('년/월', fontsize= 20)
ax.set_ylabel('검색량', fontsize= 20)
ax.grid(axis='y')
plt.savefig('부암동 검색량 추이')
plt.show()
# Out:
# <ipython-input-1000-e79499d8d630>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %%
plt.figure(figsize= (18,6))
plt.plot(a2, color = '#3f51b5', marker = 'o', linewidth = 3, markersize= 8)
ax = plt.subplot()
ax.set_facecolor('#eeeeee')
ax.set_xticks(range(len(a1)))
ax.set_xticklabels(a2.index, fontsize= 12, rotation = 30)
ax.set_yticks([8,10,12,14,16])
ax.set_yticklabels([8,10,12,14,16], fontsize= 12)
ax.set_title('평창동 검색량 추이', fontsize= 25)
ax.set_xlabel('년/월', fontsize= 20)
ax.set_ylabel('검색량', fontsize= 20)
ax.grid(axis='y')
plt.savefig('평창동 검색량 추이')
plt.show()
# Out:
# <ipython-input-1005-794e78a9002e>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %%
plt.figure(figsize= (18,6))
plt.plot(a3, color = '#ab47bc', marker = 'o', linewidth = 3, markersize= 8)
ax = plt.subplot()
ax.set_facecolor('#eeeeee')
ax.set_xticks(range(len(a1)))
ax.set_xticklabels(a3.index, fontsize= 12, rotation = 30)
ax.set_yticks([2,4,6,8,10,12,14])
ax.set_yticklabels([2,4,6,8,10,12,14], fontsize= 12)
ax.set_title('이화동 검색량 추이', fontsize= 25)
ax.set_xlabel('년/월', fontsize= 20)
ax.set_ylabel('검색량', fontsize= 20)
ax.grid(axis='y')
plt.savefig('이화동 검색량 추이')
plt.show()
# Out:
# <ipython-input-1008-3742a953a5ca>:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()
